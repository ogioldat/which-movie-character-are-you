# %%
# %load_ext autoreload
# %autoreload 2

# %%
from quiz.graph import build_chars_graph
from pyvis.network import Network
import os

graph = build_chars_graph("data/characters.json")

net = Network(height="750px", width="100%", bgcolor="#222222", font_color="white", notebook=True, cdn_resources='in_line')

net.from_nx(graph)

# Generate and save the HTML file
# html_filepath = "character_graph.html"
# net.show(html_filepath, notebook=True)

graoph
# Out:
# graph.html
#         <iframe
#             width="100%"
#             height="750px"
#             src="graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
